# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ! python -m pip install --upgrade pip -q
# ! pip install nrsur_catalog -q
# ! pip install -e "git+https://github.com/cjhaster/NRSurrogateCatalog@main#egg=nrsur_catalog" -q

# %% [markdown]
# # GW202612
#
# Below are some plots for GW202612 from the NRSurrogate Catalog.

# %%
from nrsur_catalog import NRsurResult

# %%
nrsur_result = NRsurResult.load("GW202612")
# cache_dir is where the events will be downloaded to (defaults to "~/.nrsur_catalog_cache")
nrsur_result.posterior_summary()
# Out:
# |NURSUR CATALOG|22/02 16:54:13|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|22/02 16:54:13|DEBUG| GW202612 not in ['GW170729', 'GW180756', 'GW181242', 'GW190402', 'GW192102', 'GW201992'], downloading...
# |NURSUR CATALOG|22/02 16:54:13|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|22/02 16:54:13|DEBUG| Could not parse event name from https://sandbox.zenodo.org/api/files/9372376b-2828-467e-9940-09d12a43e95d/test.json
# |NURSUR CATALOG|22/02 16:54:13|DEBUG| Could not parse event name from https://sandbox.zenodo.org/api/files/9372376b-2828-467e-9940-09d12a43e95d/tmp_bogus_0.2617134886723267.txt
# |NURSUR CATALOG|22/02 16:54:13|DEBUG| Could not parse event name from https://sandbox.zenodo.org/api/files/9372376b-2828-467e-9940-09d12a43e95d/tmp_bogus_0.3353181914080371.txt
# |NURSUR CATALOG|22/02 16:54:13|DEBUG| Could not parse event name from https://sandbox.zenodo.org/api/files/9372376b-2828-467e-9940-09d12a43e95d/tmp_bogus_0.34377217756885825.txt
# |NURSUR CATALOG|22/02 16:54:13|DEBUG| Could not parse event name from https://sandbox.zenodo.org/api/files/9372376b-2828-467e-9940-09d12a43e95d/tmp_bogus_0.9297447985099586.txt
# |NURSUR CATALOG|22/02 16:54:13|DEBUG| Could not parse event name from https://sandbox.zenodo.org/api/files/9372376b-2828-467e-9940-09d12a43e95d/tmp_bogus_0.9538792287577549.txt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qt/rxjvm_j566v9qn7g754s1v9hzb3p7f/T/ipykernel_72925/1735102995.py in <cell line: 1>()
# ----> 1 nrsur_result = NRsurResult.load("GW202612")
#       2 # cache_dir is where the events will be downloaded to (defaults to "~/.nrsur_catalog_cache")
#       3 nrsur_result.posterior_summary()
#
# ~/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/nrsur_result.py in load(cls, event_name, cache_dir)
#      49         if CACHE.find(event_name) is None:
#      50             logger.debug(f"{event_name} not in {CACHE.event_names}, downloading...")
# ---> 51             download_event(event_name, cache_dir)
#      52         event_path = CACHE.find(event_name)
#      53         r = cls.from_json(event_path)
#
# ~/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/api/download_event.py in download_event(event_name, cache_dir)
#      56     analysed_events = ZenodoInterface.get_event_urls()
#      57     if event_name not in analysed_events:
# ---> 58         raise ValueError(
#      59             f"{event_name} has not been analysed yet -- please choose from {list(analysed_events.keys())}"
#      60         )
#
# ValueError: GW202612 has not been analysed yet -- please choose from ['GW150914', 'GW170729', 'GW180756', 'GW181242', 'GW190402', 'GW192102', 'GW201992', 'GW203566', 'GW205890', 'GW206883', None]

# %%
fig = nrsur_result.plot_corner(["mass_1", "mass_2", "chirp_mass", "mass_ratio"])

# %%
fig = nrsur_result.plot_corner(["a_1", "a_2", "tilt_1", "tilt_2"])

# %%
fig = nrsur_result.plot_corner(["mass_ratio", "chi_eff", "chi_p"])

# %%
fig = nrsur_result.plot_corner(["luminosity_distance", "ra", "dec"])

# %%
fig = nrsur_result.plot_signal(outdir=".")
