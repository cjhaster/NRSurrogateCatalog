# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)

! python -m pip install --upgrade pip -q
! pip install "nrsur_catalog @ git+https://github.com/cjhaster/NRSurrogateCatalog@main#egg" -q

# %% [markdown]
# # GW192102
#
# Below are some plots for GW192102 from the NRSurrogate Catalog.

# %%
from nrsur_catalog import NRsurResult
nrsur_result = NRsurResult.load("GW192102")
# you can specify a `cache_dir`: folder where data will be downloaded (defaults to "~/.nrsur_catalog_cache")
# Out:
# Bad value in file '/Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/style.mplstyle', line 7 ("mathtext.fontset: 'custom'"): Key mathtext.fontset: "'custom'" is not a valid value for mathtext.fontset; supported values are ['dejavusans', 'dejavuserif', 'cm', 'stix', 'stixsans', 'custom']; remove quotes surrounding your string
# |NURSUR CATALOG|03/03 16:23:18|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir

# %%
nrsur_result.posterior_summary()
# Out:
#                                   Posterior 90% CI  \
# Parameter
# mass_1                 ${86.40}_{-14.87}^{+14.30}$
# mass_2                 ${68.06}_{-10.57}^{+11.27}$
# chirp_mass             ${66.68}_{-10.46}^{+10.06}$
# mass_ratio                ${0.80}_{-0.09}^{+0.10}$
# a_1                       ${0.10}_{-0.06}^{+0.09}$
# a_2                       ${0.55}_{-0.10}^{+0.10}$
# tilt_1                    ${1.25}_{-0.64}^{+0.78}$
# tilt_2                    ${2.02}_{-0.78}^{+0.62}$
# chi_eff                  ${-0.08}_{-0.12}^{+0.17}$
# chi_p                     ${0.32}_{-0.14}^{+0.12}$
# ra                        ${3.03}_{-0.84}^{+0.76}$
# dec                       ${0.72}_{-0.66}^{+0.54}$
# luminosity_distance  ${3631.87}_{-99.07}^{+93.88}$
# phase                     ${3.05}_{-0.78}^{+0.81}$
# psi                       ${2.06}_{-0.76}^{+0.64}$
# phi_jl                    ${4.30}_{-0.76}^{+0.69}$
# phi_12                    ${2.47}_{-0.80}^{+0.81}$
# phi_jl                    ${4.30}_{-0.76}^{+0.69}$
# theta_jn                  ${1.02}_{-0.63}^{+0.75}$
#
#                                                                  Prior
# Parameter
# mass_1               Constraint(minimum=5, maximum=100, name='mass_...
# mass_2               Constraint(minimum=5, maximum=100, name='mass_...
# chirp_mass           bilby.gw.prior.UniformInComponentsChirpMass(mi...
# mass_ratio           bilby.gw.prior.UniformInComponentsMassRatio(mi...
# a_1                  Uniform(minimum=0, maximum=0.99, name='a_1', l...
# a_2                  Uniform(minimum=0, maximum=0.99, name='a_2', l...
# tilt_1               Sine(minimum=0, maximum=3.141592653589793, nam...
# tilt_2               Sine(minimum=0, maximum=3.141592653589793, nam...
# chi_eff                                                             NA
# chi_p                                                               NA
# ra                   Uniform(minimum=0, maximum=6.283185307179586, ...
# dec                  Cosine(minimum=-1.5707963267948966, maximum=1....
# luminosity_distance  bilby.gw.prior.UniformSourceFrame(minimum=100....
# phase                Uniform(minimum=0, maximum=6.283185307179586, ...
# psi                  Uniform(minimum=0, maximum=3.141592653589793, ...
# phi_jl               Uniform(minimum=0, maximum=6.283185307179586, ...
# phi_12               Uniform(minimum=0, maximum=6.283185307179586, ...
# phi_jl               Uniform(minimum=0, maximum=6.283185307179586, ...
# theta_jn             Sine(minimum=0, maximum=3.141592653589793, nam...

# %% [markdown]
# ## Corner Plots
# ### Mass

# %%
fig = nrsur_result.plot_corner(["mass_1", "mass_2", "chirp_mass", "mass_ratio"])
# Out:
# findfont: Font family ["'sans-serif'"] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Spin

# %%
fig = nrsur_result.plot_corner(["a_1", "a_2", "tilt_1", "tilt_2"])

# %%
fig = nrsur_result.plot_corner(["mass_ratio", "chi_eff", "chi_p"])

# %% [markdown]
# ### Sky-localisation

# %%
fig = nrsur_result.plot_corner(["luminosity_distance", "ra", "dec"])

# %% [markdown]
# ## Waveform posterior-predictive plot

# %%
fig = nrsur_result.plot_signal(outdir=".")
# Out:
# XLAL Error - NRSur7dq4_Init_LALDATA (LALSimIMRPrecessingNRSur.c:184): Unable to resolve data file NRSur7dq4.h5 in $LAL_DATA_PATH
#
# XLAL Error - NRSur7dq4_Init_LALDATA (LALSimIMRPrecessingNRSur.c:184): I/O error
# XLAL Error - PrecessingNRSur_core (LALSimIMRPrecessingNRSur.c:1836): Error loading surrogate data.
#
# XLAL Error - PrecessingNRSur_core (LALSimIMRPrecessingNRSur.c:1836): Generic failure
# XLAL Error - XLALSimInspiralChooseTDWaveform (LALSimInspiral.c:1232): Internal function call failed: Generic failure
# XLAL Error - XLALSimInspiralTDFromTD (LALSimInspiral.c:2533): Internal function call failed: Generic failure
# XLAL Error - XLALSimInspiralTD (LALSimInspiral.c:2780): Internal function call failed: Generic failure
# XLAL Error - XLALSimInspiralFD (LALSimInspiral.c:3021): Internal function call failed: Generic failure
# |NURSUR CATALOG|03/03 16:23:28|WARNING| Unable to create a waveform: do you have NrSur7dq4 installed? Defaulting to IMRPhenomPv2

# %% [markdown]
# ## Analysis configs
# Below are the configs used for the analysis of this job.

# %%
nrsur_result.print_configs()
# Out:
# |NURSUR CATALOG|03/03 16:23:41|INFO| To be implemented...

# %% [markdown]
# Download the analysis datafiles with the following (you can specify an outdir)

# %%
nrsur_result.download_analysis_datafiles()
# Out:
# |NURSUR CATALOG|03/03 16:23:41|INFO| Saving files to outdir_GW192102
# |NURSUR CATALOG|03/03 16:23:41|INFO| To be implemented...
# |NURSUR CATALOG|03/03 16:23:41|INFO| Downloading analysis strain
# |NURSUR CATALOG|03/03 16:23:41|INFO| Downloading PSDs
# |NURSUR CATALOG|03/03 16:23:41|INFO| Downloading calibration files
# |NURSUR CATALOG|03/03 16:23:41|INFO| writing analysis config file
# |NURSUR CATALOG|03/03 16:23:41|INFO| Files:
