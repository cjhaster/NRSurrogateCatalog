# %%
# %matplotlib inline

# %% [markdown]
# # Catalog plots
#
# Here we have some catalog plots showing the ensemble results of the catalog (working on making these plotly-plots).

# %%
from nrsur_catalog import Catalog

catalog = Catalog.load()
# Out:
# |NURSUR CATALOG|03/03 17:54:00|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# Loading events:   0%|          | 0/10 [00:00<?, ?it/s]
# |NURSUR CATALOG|03/03 17:54:00|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|03/03 17:54:01|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|03/03 17:54:02|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|03/03 17:54:02|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|03/03 17:54:02|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|03/03 17:54:02|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|03/03 17:54:02|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|03/03 17:54:02|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|03/03 17:54:02|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir
# |NURSUR CATALOG|03/03 17:54:02|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/tests/test_events_dir

# %% [markdown]
# ## Mass 1

# %%
catalog.violin_plot("mass_1")
# Out:
# findfont: Font family ["'sans-serif'"] not found. Falling back to DejaVu Sans.
# findfont: Font family ["'sans-serif'"] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'cursive' not found because none of the following families were found: 'Liberation Sans'
# findfont: Font family ['sans'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans' not found because none of the following families were found: 'Liberation Sans'
# findfont: Font family ['sans'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans' not found because none of the following families were found: 'Liberation Sans'
# findfont: Font family ['sans'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans' not found because none of the following families were found: 'Liberation Sans'

# %% [markdown]
# ## Mass Ratio

# %%
catalog.violin_plot("mass_ratio")

# %% [markdown]
# ## Chi Eff

# %%
catalog.violin_plot("chi_eff")

# %% [markdown]
# ````{tab} Mass 1
# ![mass_1_violin.png](mass_1_violin.png)
# ````
# ````{tab} Mass Ratio
# ![mass_ratio_violin.png](mass_ratio_violin.png)
# ````
# ````{tab} Chi Eff
# ![chi_eff_violin.png](chi_eff_violin.png)
# ````

# %% [markdown]
# ## Interactive violin 1

# %%
catalog.interactive_violin_plot("mass_1")
# Out:
# FigureWidget({
#     'data': [{'box': {'visible': True},
#               'fillcolor': 'orange',
#               'lin…

# %% [markdown]
# ## Interactive violin 2

# %%
catalog.interactive_violin_2("mass_1")
# Out:
# FigureWidget({
#     'data': [{'box': {'visible': True},
#               'meanline': {'visible': True},
#           …
